# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Average Wind Speed Data of Nepal from different Districts (2005 - 2016)
# <br>
# <li>Last Modified: July 6, 2019
# <li>Data Format: CSV

# %% [markdown]
# # Reading the Wind Speed Data

# %%
dataset = pd.read_csv('average-wind-speed-by-station-km_hr.csv')

# %%
df = pd.DataFrame(dataset)

# %% [markdown]
# # Analyzing the Dataset

# %%
df = df.T
df.head()
# Out:
#                                      0                    1   \
# Station Name  Arghakhanchi (Khanchikot)  Bardia (Chishapani)
# 2005                                6.6                  7.2
# 2006                                NaN                  NaN
# 2007                                NaN                  NaN
# 2008                                NaN                  NaN
#
#                                             2                 3   \
# Station Name  Rupandehi,Bhairahawa Agriculture  Bhojpur,Bhojpur*
# 2005                                       2.7                 -
# 2006                                       2.7                 -
# 2007                                       NaN                 -
# 2008                                       NaN                 -
#
#                                  4                   5                   6   \
# Station Name  Dadeldhura,Dadeldhura  Dhankuta,Pakhribas  Dhankuta, Dhankuta
# ...

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=32, step=1)

# %%
df = df.rename(index={'Station Name':'Year'})

# %%
df.head(13)
# Out:
#                              0                    1   \
# Year  Arghakhanchi (Khanchikot)  Bardia (Chishapani)
# 2005                        6.6                  7.2
# 2006                        NaN                  NaN
# 2007                        NaN                  NaN
# 2008                        NaN                  NaN
# 2009                        NaN                  NaN
# 2010                        NaN                  NaN
# 2011                        NaN                  NaN
# 2012                        NaN                  NaN
# 2013                        NaN                  NaN
# 2014                        NaN                  NaN
# 2015                        NaN                  NaN
# 2016                        NaN                  NaN
#
#                                     2                 3   \
# Year  Rupandehi,Bhairahawa Agriculture  Bhojpur,Bhojpur*
# 2005                               2.7                 -
# ...

# %% [markdown]
# # Dropping the Column with no records
# <h3>The district with no records are:</h3>
# <li>Bhojpur</li>
# <li>Jhapa</li>
# <li>Mustang</li>

# %%
df = df.drop([3,10,11],axis = 1)

# %% [markdown]
# <p>The indexes without values are represented with strings like "N.A" rather than NaNs. So they are first replaced with NaNs.</p>

# %%
df.columns = range(29)
df = df.replace(['N.A'],np.nan)

# df[4][3] = 2.6
# df[4][5] = 2.8
# df[6][3] = 3.2
# df[6][5] = 3.1
# df[24][3] = 1.9
# df[25][5] = 1.1
# df[27][4] = 1.6
# df[27][5] = 1

df
# Out:
#                              0                    1   \
# Year  Arghakhanchi (Khanchikot)  Bardia (Chishapani)
# 2005                        6.6                  7.2
# 2006                        NaN                  NaN
# 2007                        NaN                  NaN
# 2008                        NaN                  NaN
# 2009                        NaN                  NaN
# 2010                        NaN                  NaN
# 2011                        NaN                  NaN
# 2012                        NaN                  NaN
# 2013                        NaN                  NaN
# 2014                        NaN                  NaN
# 2015                        NaN                  NaN
# 2016                        NaN                  NaN
#
#                                     2                      3   \
# Year  Rupandehi,Bhairahawa Agriculture  Dadeldhura,Dadeldhura
# 2005                               2.7                    3.4
# ...

# %%
trans = df.T
trans
# Out:
#                                 Year 2005 2006 2007 2008  2009  2010  2011  \
# 0          Arghakhanchi (Khanchikot)  6.6  NaN  NaN  NaN   NaN   NaN   NaN
# 1                Bardia (Chishapani)  7.2  NaN  NaN  NaN   NaN   NaN   NaN
# 2   Rupandehi,Bhairahawa Agriculture  2.7  2.7  NaN  NaN   NaN   NaN   NaN
# 3              Dadeldhura,Dadeldhura  3.4  2.9  2.6  2.6   2.8   NaN  2.11
# 4                 Dhankuta,Pakhribas  1.2  1.3  NaN  0.9   NaN   NaN   NaN
# 5                 Dhankuta, Dhankuta  3.9  3.5  3.2  3.3   3.1   2.9  2.51
# 6                     Dolakha (Jiri)  3.2  3.1  NaN    3   NaN   3.2  2.92
# 7                      Doti, Dipayal  1.4    2  1.9  1.5   1.6   NaN   NaN
# 8              Ilam , Ilam Tea State  1.2  1.2  NaN  NaN   NaN   NaN   NaN
# 9                        Jumla,Jumla  5.4  5.6  5.3  4.6   4.8   4.4  4.16
# 10                 Kailai, Dhangadhi  NaN  NaN  1.7  1.7   1.6   NaN   NaN
# ...

# %%
cols = []
for i in range(29):
    cols.append(df[i][0])
print(cols)
len(cols)
# Out:
# ['Arghakhanchi (Khanchikot)', 'Bardia (Chishapani)', 'Rupandehi,Bhairahawa Agriculture', 'Dadeldhura,Dadeldhura', 'Dhankuta,Pakhribas', 'Dhankuta, Dhankuta', 'Dolakha (Jiri)', 'Doti, Dipayal', 'Ilam , Ilam Tea State', 'Jumla,Jumla', 'Kailai, Dhangadhi', 'Kanchanpur,Mahendranagar', 'Kaski ,Lumle', 'Kathmandu ,Kathmandu Airport', 'Lalitpur ,Khumaltar', 'Kaski, Malepatan', 'Morang, Biratnagar Airport', 'Bhaktpur, Nagarkot', 'Banke, Nepalganj', 'Banke,Khajura', 'Banke, Sikta', 'Okhaldhunga,Okhaldhunga', 'Parsa, Parwanipur', 'Kaski, Pokhara Airport', 'Siraha, Lahan', 'Sunsari ,Tarahara', 'Surkhet ,Birendranagar', 'Surkhet ,Pusmacamp', 'Taplejung, Taplejung']
# 29

# %%
df.columns = cols

# %%
df.index
# Out:
# Index(['Year', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016'],
#       dtype='object')

# %%
df = df.drop(["Year"],axis=0)

# %%
df.columns
# Out:
# Index(['Arghakhanchi (Khanchikot)', 'Bardia (Chishapani)',
#        'Rupandehi,Bhairahawa Agriculture', 'Dadeldhura,Dadeldhura',
#        'Dhankuta,Pakhribas', 'Dhankuta, Dhankuta', 'Dolakha (Jiri)',
#        'Doti, Dipayal', 'Ilam , Ilam Tea State', 'Jumla,Jumla',
#        'Kailai, Dhangadhi', 'Kanchanpur,Mahendranagar', 'Kaski ,Lumle',
#        'Kathmandu ,Kathmandu Airport', 'Lalitpur ,Khumaltar',
#        'Kaski, Malepatan', 'Morang, Biratnagar Airport', 'Bhaktpur, Nagarkot',
#        'Banke, Nepalganj', 'Banke,Khajura', 'Banke, Sikta',
#        'Okhaldhunga,Okhaldhunga', 'Parsa, Parwanipur',
#        'Kaski, Pokhara Airport', 'Siraha, Lahan', 'Sunsari ,Tarahara',
#        'Surkhet ,Birendranagar', 'Surkhet ,Pusmacamp', 'Taplejung, Taplejung'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Arghakhanchi (Khanchikot)           object
# Bardia (Chishapani)                 object
# Rupandehi,Bhairahawa Agriculture    object
# Dadeldhura,Dadeldhura               object
# Dhankuta,Pakhribas                  object
# Dhankuta, Dhankuta                  object
# Dolakha (Jiri)                      object
# Doti, Dipayal                       object
# Ilam , Ilam Tea State               object
# Jumla,Jumla                         object
# Kailai, Dhangadhi                   object
# Kanchanpur,Mahendranagar            object
# Kaski ,Lumle                        object
# Kathmandu ,Kathmandu Airport        object
# Lalitpur ,Khumaltar                 object
# Kaski, Malepatan                    object
# Morang, Biratnagar Airport          object
# Bhaktpur, Nagarkot                  object
# Banke, Nepalganj                    object
# Banke,Khajura                       object
# Banke, Sikta                        object
# Okhaldhunga,Okhaldhunga             object
# ...

# %%
df = df.astype(float)

# %%
meean = df['Arghakhanchi (Khanchikot)'].mean()
for place in cols:
    df[place] = df[place].fillna(df[place].mean())
df
# Out:
#       Arghakhanchi (Khanchikot)  Bardia (Chishapani)  \
# 2005                        6.6                  7.2
# 2006                        6.6                  7.2
# 2007                        6.6                  7.2
# 2008                        6.6                  7.2
# 2009                        6.6                  7.2
# 2010                        6.6                  7.2
# 2011                        6.6                  7.2
# 2012                        6.6                  7.2
# 2013                        6.6                  7.2
# 2014                        6.6                  7.2
# 2015                        6.6                  7.2
# 2016                        6.6                  7.2
#
#       Rupandehi,Bhairahawa Agriculture  Dadeldhura,Dadeldhura  \
# 2005                           2.70000               3.400000
# 2006                           2.70000               2.900000
# 2007                           1.58525               2.600000
# ...

# %%
df = df.append(df.sum().rename('Total'))
df
# Out:
#        Arghakhanchi (Khanchikot)  Bardia (Chishapani)  \
# 2005                         6.6                  7.2
# 2006                         6.6                  7.2
# 2007                         6.6                  7.2
# 2008                         6.6                  7.2
# 2009                         6.6                  7.2
# 2010                         6.6                  7.2
# 2011                         6.6                  7.2
# 2012                         6.6                  7.2
# 2013                         6.6                  7.2
# 2014                         6.6                  7.2
# 2015                         6.6                  7.2
# 2016                         6.6                  7.2
# Total                       79.2                 86.4
#
#        Rupandehi,Bhairahawa Agriculture  Dadeldhura,Dadeldhura  \
# 2005                            2.70000               3.400000
# 2006                            2.70000               2.900000
# ...

# %%
trans = df.T
trans
# Out:
#                                     2005      2006      2007     2008  \
# Arghakhanchi (Khanchikot)         6.6000  6.600000  6.600000  6.60000
# Bardia (Chishapani)               7.2000  7.200000  7.200000  7.20000
# Rupandehi,Bhairahawa Agriculture  2.7000  2.700000  1.585250  1.58525
# Dadeldhura,Dadeldhura             3.4000  2.900000  2.600000  2.60000
# Dhankuta,Pakhribas                1.2000  1.300000  1.917571  0.90000
# Dhankuta, Dhankuta                3.9000  3.500000  3.200000  3.30000
# Dolakha (Jiri)                    3.2000  3.100000  2.613333  3.00000
# Doti, Dipayal                     1.4000  2.000000  1.900000  1.50000
# Ilam , Ilam Tea State             1.2000  1.200000  1.200000  1.20000
# Jumla,Jumla                       5.4000  5.600000  5.300000  4.60000
# Kailai, Dhangadhi                 1.0684  1.068400  1.700000  1.70000
# Kanchanpur,Mahendranagar          2.4000  2.100000  2.250000  2.25000
# ...

# %%
df.shape
# Out:
# (13, 29)

# %% [markdown]
# # Getting the Final Result

# %%
over50 = trans.query('Total > 50')
bet50_30 = trans.query('Total > 30 and Total < 50')
bet30_20 = trans.query('Total > 20 and Total < 30')
over20 = trans.query('Total > 20')

# %%
over50
# Out:
#                            2005  2006  2007  2008      2009  2010      2011  \
# Arghakhanchi (Khanchikot)   6.6   6.6   6.6   6.6  6.600000   6.6  6.600000
# Bardia (Chishapani)         7.2   7.2   7.2   7.2  7.200000   7.2  7.200000
# Jumla,Jumla                 5.4   5.6   5.3   4.6  4.800000   4.4  4.160000
# Sunsari ,Tarahara           4.5   7.0   6.4   6.2  5.438778   6.3  5.438778
#
#                                2012   2013   2014  2015   2016      Total
# Arghakhanchi (Khanchikot)  6.600000  6.600  6.600  6.60  6.600  79.200000
# Bardia (Chishapani)        7.200000  7.200  7.200  7.20  7.200  86.400000
# Jumla,Jumla                4.666727  4.058  4.208  4.55  4.258  56.000727
# Sunsari ,Tarahara          5.438778  4.775  4.608  4.55  4.616  65.265333

# %%
bet50_30
# Out:
#                             2005      2006      2007  2008      2009  2010  \
# Dhankuta, Dhankuta           3.9  3.500000  3.200000   3.3  3.100000   2.9
# Dolakha (Jiri)               3.2  3.100000  2.613333   3.0  2.613333   3.2
# Lalitpur ,Khumaltar          3.0  3.000000  3.000000   3.2  3.000000   3.0
# Morang, Biratnagar Airport   1.8  3.641429  5.900000   6.5  5.000000   2.8
# Okhaldhunga,Okhaldhunga      2.7  4.300000  4.300000   3.8  2.000000   2.3
#
#                             2011      2012      2013      2014      2015  \
# Dhankuta, Dhankuta          2.51  2.540000  1.859000  1.616000  2.842500
# Dolakha (Jiri)              2.92  2.613333  3.383000  2.025000  1.325000
# Lalitpur ,Khumaltar         2.68  2.855400  2.633000  2.855400  2.558000
# Morang, Biratnagar Airport  1.24  2.250000  3.641429  3.641429  3.641429
# Okhaldhunga,Okhaldhunga     2.03  4.760000  4.008000  3.150000  2.983000
#
#                                 2016      Total
# ...

# %%
bet30_20
# Out:
#                           2005      2006      2007  2008      2009      2010  \
# Dadeldhura,Dadeldhura      3.4  2.900000  2.600000  2.60  2.800000  2.360857
# Dhankuta,Pakhribas         1.2  1.300000  1.917571  0.90  1.917571  1.917571
# Kanchanpur,Mahendranagar   2.4  2.100000  2.250000  2.25  2.250000  2.250000
# Bhaktpur, Nagarkot         4.3  3.700000  2.900000  2.70  0.900000  1.993444
# Banke,Khajura              2.2  1.900000  1.900000  1.90  1.800000  1.940000
# Kaski, Pokhara Airport     2.3  2.323143  1.900000  2.10  2.300000  2.323143
# Siraha, Lahan              3.9  2.410250  2.410250  1.90  1.100000  2.410250
# Surkhet ,Birendranagar     1.6  1.200000  1.300000  1.60  1.000000  1.965167
# Surkhet ,Pusmacamp         1.6  1.900000  1.600000  1.70  1.700000  1.700000
#
#                               2011      2012      2013      2014      2015  \
# Dadeldhura,Dadeldhura     2.110000  2.360857  0.116000  2.360857  2.360857
# ...

# %%
over20
# Out:
#                             2005      2006      2007  2008      2009  \
# Arghakhanchi (Khanchikot)    6.6  6.600000  6.600000  6.60  6.600000
# Bardia (Chishapani)          7.2  7.200000  7.200000  7.20  7.200000
# Dadeldhura,Dadeldhura        3.4  2.900000  2.600000  2.60  2.800000
# Dhankuta,Pakhribas           1.2  1.300000  1.917571  0.90  1.917571
# Dhankuta, Dhankuta           3.9  3.500000  3.200000  3.30  3.100000
# Dolakha (Jiri)               3.2  3.100000  2.613333  3.00  2.613333
# Jumla,Jumla                  5.4  5.600000  5.300000  4.60  4.800000
# Kanchanpur,Mahendranagar     2.4  2.100000  2.250000  2.25  2.250000
# Lalitpur ,Khumaltar          3.0  3.000000  3.000000  3.20  3.000000
# Morang, Biratnagar Airport   1.8  3.641429  5.900000  6.50  5.000000
# Bhaktpur, Nagarkot           4.3  3.700000  2.900000  2.70  0.900000
# Banke,Khajura                2.2  1.900000  1.900000  1.90  1.800000
# Okhaldhunga,Okhaldhunga      2.7  4.300000  4.300000  3.80  2.000000
# ...

# %% [markdown]
# # Saving the CSV File

# %%
trans.to_csv('FinalResult.csv')

# %% [markdown]
# # Visualization

# %%
over50.plot.bar()

# %%
over20.plot.bar()

# %%
bet50_30.plot.bar()

# %%
bet30_20.plot.bar()

# %% [markdown]
# # Conclusion

# %% [markdown]
# <p>Wind is caused by the uneven heating of the atmosphere by the sun, variations in the earth's surface and rotation of the earth. Furthermore, Mountains, bodies of water, and vegetation all influence wind flow patterns. Wind energy can be a major source of energy in our country.</p>
# <p>The amount of energy produced by wind is solely dependent on the speed of wind. Likewise, the speed of wind is unevenly distributed in different places of the country. So, if the Wind Mills can be deployed on the places with the higher wind flows then maximum amount of energy can be produced. So, the main purpose of this data analysis is to find out which region is most suitable to produce higher amount of energy when it comes to wind.</p>
#
# <p>In conclusion, the windmills should be deployed on the following regions on chronological order in order to generate higher amount of energies:</p>
# <li>Bardia (Chishapani)</li>
# <li>Arghakhanchi (Khanchikot)</li>
# <li>Sunsari ,Tarahara</li>
# <li>Jumla,Jumla</li>
# <li>Morang, Biratnagar Airport</li>
# <li>Okhaldhunga,Okhaldhunga	</li>...
