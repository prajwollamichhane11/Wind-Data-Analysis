# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Average Wind Speed Data of Nepal from different Districts (2005 - 2016)
# <br>
# <li>Last Modified: July 6, 2019
# <li>Data Format: CSV

# %%
dataset = pd.read_csv('average-wind-speed-by-station-km_hr.csv')

# %%
df = pd.DataFrame(dataset)
real = df

# %%
df = df.T

# %%
df = df.rename(index={'Station Name':'Year'})

# %%
df.head(13)
# Out:
#                              0                    1   \
# Year  Arghakhanchi (Khanchikot)  Bardia (Chishapani)
# 2005                        6.6                  7.2
# 2006                        NaN                  NaN
# 2007                        NaN                  NaN
# 2008                        NaN                  NaN
# 2009                        NaN                  NaN
# 2010                        NaN                  NaN
# 2011                        NaN                  NaN
# 2012                        NaN                  NaN
# 2013                        NaN                  NaN
# 2014                        NaN                  NaN
# 2015                        NaN                  NaN
# 2016                        NaN                  NaN
#
#                                     2                 3   \
# Year  Rupandehi,Bhairahawa Agriculture  Bhojpur,Bhojpur*
# 2005                               2.7                 -
# ...

# %%
df = df.drop([3,10,11],axis = 1)

# %%
df.columns = range(29)

# %%
for i in range(len(df)):
    new_df[i] = new_df[i].fillna(mean_age)
